# %%
# !pip install db-dtypes
# Out:
# Requirement already satisfied: db-dtypes in c:\users\user\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\user\anaconda3\lib\site-packages (from db-dtypes) (2.3.5)
# Requirement already satisfied: packaging>=24.2.0 in c:\users\user\anaconda3\lib\site-packages (from db-dtypes) (25.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\user\anaconda3\lib\site-packages (from db-dtypes) (2.3.3)
# Requirement already satisfied: pyarrow>=13.0.0 in c:\users\user\anaconda3\lib\site-packages (from db-dtypes) (21.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.5.3->db-dtypes) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.3->db-dtypes) (1.17.0)

# %%
import db_dtypes
print("db-dtypes OK")
# Out:
# db-dtypes OK

# %%
query = """
SELECT *
FROM `gdelt-bq.gdeltv2.events`
WHERE
    (
        ActionGeo_CountryCode = 'BN'
        OR Actor1CountryCode = 'BEN'
        OR Actor2CountryCode = 'BEN'
    )
AND Year >= 2025
LIMIT 10000
"""

df_benin = client.query(query).to_dataframe()

print(df_benin.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:61
#      60 try:
# ---> 61     import db_dtypes  # type: ignore
#      63     date_dtype_name = db_dtypes.DateDtype.name
#
# ModuleNotFoundError: No module named 'db_dtypes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 14
#       1 query = """
#       2 SELECT *
#       3 FROM `gdelt-bq.gdeltv2.events`
#    (...)     11 LIMIT 10000
#      12 """
# ---> 14 df_benin = client.query(query).to_dataframe()
#      16 print(df_benin.shape)
#
# File ~\anaconda3\Lib\site-packages\google\cloud\bigquery\job\query.py:2195, in QueryJob.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype, timeout)
#    1984 """Return a pandas DataFrame from a QueryJob
#    1985
#    1986 Args:
#    (...)   2192         :mod:`shapely` library cannot be imported.
#    2193 """
#    2194 query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
# -> 2195 return query_result.to_dataframe(
#    2196     bqstorage_client=bqstorage_client,
#    2197     dtypes=dtypes,
#    2198     progress_bar_type=progress_bar_type,
#    2199     create_bqstorage_client=create_bqstorage_client,
#    2200     geography_as_object=geography_as_object,
#    2201     bool_dtype=bool_dtype,
#    2202     int_dtype=int_dtype,
#    2203     float_dtype=float_dtype,
#    2204     string_dtype=string_dtype,
#    2205     date_dtype=date_dtype,
#    2206     datetime_dtype=datetime_dtype,
#    2207     time_dtype=time_dtype,
#    2208     timestamp_dtype=timestamp_dtype,
#    2209     range_date_dtype=range_date_dtype,
#    2210     range_datetime_dtype=range_datetime_dtype,
#    2211     range_timestamp_dtype=range_timestamp_dtype,
#    2212     timeout=timeout,
#    2213 )
#
# File ~\anaconda3\Lib\site-packages\google\cloud\bigquery\table.py:2714, in RowIterator.to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype, range_date_dtype, range_datetime_dtype, range_timestamp_dtype, timeout)
#    2474 def to_dataframe(
#    2475     self,
#    2476     bqstorage_client: Optional["bigquery_storage.BigQueryReadClient"] = None,
#    (...)   2496     timeout: Optional[float] = None,
#    2497 ) -> "pandas.DataFrame":
#    2498     """Create a pandas DataFrame by loading all pages of a query.
#    2499
#    2500     Args:
#    (...)   2712
#    2713     """
# -> 2714     _pandas_helpers.verify_pandas_imports()
#    2716     if geography_as_object and shapely is None:
#    2717         raise ValueError(_NO_SHAPELY_ERROR)
#
# File ~\anaconda3\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:1172, in verify_pandas_imports()
#    1170     raise ValueError(_NO_PANDAS_ERROR) from pandas_import_exception
#    1171 if db_dtypes is None:
# -> 1172     raise ValueError(_NO_DB_TYPES_ERROR) from db_dtypes_import_exception
#
# ValueError: Please install the 'db-dtypes' package to use this function.
